# %% [markdown]
# # COSC2753 - Assignment 2: Task 2 - RMIT University
# **Paddy Variety Classification - Fine-tuning MobileNetV2**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
TRAIN_DIR = '../data/train_images'
NUM_CLASSES = len(os.listdir(TRAIN_DIR))

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_gen = datagen.flow_from_directory(
    directory=TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    directory=TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 8330 images belonging to 10 classes.
# Found 2077 images belonging to 10 classes.

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=20,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 101s 376ms/step - accuracy: 0.3931 - loss: 1.7791 - val_accuracy: 0.6143 - val_loss: 1.1099
# Epoch 2/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 102s 390ms/step - accuracy: 0.6477 - loss: 1.0525 - val_accuracy: 0.7092 - val_loss: 0.9001
# Epoch 3/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 103s 395ms/step - accuracy: 0.7160 - loss: 0.8612 - val_accuracy: 0.7405 - val_loss: 0.7901
# Epoch 4/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 180s 688ms/step - accuracy: 0.7835 - loss: 0.6789 - val_accuracy: 0.7752 - val_loss: 0.6952
# Epoch 5/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 184s 704ms/step - accuracy: 0.8145 - loss: 0.5775 - val_accuracy: 0.7954 - val_loss: 0.6305
# Epoch 6/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 180s 689ms/step - accuracy: 0.8318 - loss: 0.5221 - val_accuracy: 0.8132 - val_loss: 0.5845
# Epoch 7/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 179s 686ms/step - accuracy: 0.8645 - loss: 0.4382 - val_accuracy: 0.8382 - val_loss: 0.5230
# Epoch 8/20
# ...

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy")
plt.legend()
plt.show()

# %%
model.save("../models/model_task2.keras")

# %% [markdown]
# ## 📤 Prediction & Export Submission File

# %%
model = load_model("../models/model_task2.keras")

class_map = train_gen.class_indices
inv_class_map = {v: k for k, v in class_map.items()}

# %%
test_dir = '../data/test_images'
image_list = sorted(os.listdir(test_dir))
results = []

for image_name in image_list:
    img_path = os.path.join(test_dir, image_name)
    img = load_img(img_path, target_size=(224, 224))
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = model.predict(img_array)
    label_idx = np.argmax(prediction)
    label = inv_class_map[label_idx]
    results.append([image_name, label])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 test_dir = 'test_images'
# ----> 2 image_list = sorted(os.listdir(test_dir))
#       3 results = []
#       5 for image_name in image_list:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'test_images'

# %%
df = pd.DataFrame(results, columns=['image_id', 'variety'])
df.to_csv("prediction_submission.csv", index=False)
print("prediction_submission.csv has been saved.")
# Out:
# prediction_submission.csv has been saved.
